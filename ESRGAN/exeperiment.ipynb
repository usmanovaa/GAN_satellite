# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall torch
# !pip install torch==1.3.0
# Out:
# Uninstalling torch-1.6.0+cu101:
#   Would remove:
#     /usr/local/bin/convert-caffe2-to-onnx
#     /usr/local/bin/convert-onnx-to-caffe2
#     /usr/local/lib/python3.6/dist-packages/caffe2/*
#     /usr/local/lib/python3.6/dist-packages/torch-1.6.0+cu101.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/torch/*
# Proceed (y/n)? y
#   Successfully uninstalled torch-1.6.0+cu101
# ...
#      |████████████████████████████████| 773.1MB 22kB/s
# ...
# ERROR: torchvision 0.7.0+cu101 has requirement torch==1.6.0, but you'll have torch 1.3.0 which is incompatible.
# ...

# %%
# !pip uninstall torchvision
# !pip install torchvision==0.4.0
# Out:
# Uninstalling torchvision-0.7.0+cu101:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/torchvision-0.7.0+cu101.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/torchvision/*
# Proceed (y/n)? y
#   Successfully uninstalled torchvision-0.7.0+cu101
# ...
#      |████████████████████████████████| 8.8MB 5.5MB/s
# ...
#      |████████████████████████████████| 748.9MB 15kB/s
# ...
#   Found existing installation: torch 1.3.0
#     Uninstalling torch-1.3.0:
#       Successfully uninstalled torch-1.3.0
# ...

# %%
import torchvision
import torch
from torch import nn

# %%
# !python3 'drive/My Drive/Aerocosmos/2/train.py' --upscale_factor 4 --crop_size 32 --dataset_name 'pan_png'
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# ## Test benchmarks

# %%
# !python3 'drive/My Drive/Aerocosmos/2/test_benchmark.py' --upscale_factor 4 --model_name 'netG_epoch_4_100.pth' --dataset_name 'pan_png'
# Out:
# [testing benchmark datasets]:   0% 0/15 [00:00<?, ?it/s]tensor(0.0025, device='cuda:0') 26.04302897475629
# [testing benchmark datasets]:   7% 1/15 [00:01<00:20,  1.45s/it]tensor(0.0059, device='cuda:0') 22.27132908218674
# [testing benchmark datasets]:  13% 2/15 [00:01<00:15,  1.17s/it]tensor(0.0019, device='cuda:0') 27.19520135236501
# [testing benchmark datasets]:  20% 3/15 [00:02<00:11,  1.06it/s]tensor(0.0041, device='cuda:0') 23.83612078045249
# [testing benchmark datasets]:  27% 4/15 [00:02<00:08,  1.28it/s]tensor(0.0032, device='cuda:0') 25.005083234262273
# [testing benchmark datasets]:  33% 5/15 [00:03<00:06,  1.49it/s]tensor(0.0054, device='cuda:0') 22.690404381390522
# [testing benchmark datasets]:  40% 6/15 [00:03<00:05,  1.71it/s]tensor(0.0023, device='cuda:0') 26.395944806502722
# [testing benchmark datasets]:  47% 7/15 [00:03<00:04,  1.89it/s]tensor(0.0022, device='cuda:0') 26.480147436606487
# ...

# %% [markdown]
# ## Test image

# %%
# !python3 'drive/My Drive/Aerocosmos/2/test_image.py' --upscale_factor 4 --model_name 'netG_epoch_4_100.pth' --image_name '0259.png'
# Out:
# drive/My Drive/Aerocosmos/2/test_image.py:37: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   image = Variable(ToTensor()(image), volatile=True).unsqueeze(0)

# %%
scale = 4
filename = '3681.png'
img = io.imread(filename)
if len(img.shape) < 3:
    img_res = transform.resize(img, (img.shape[0]//scale, img.shape[1]//scale))
else: 
    img_res = transform.resize(img, (img.shape[0]//scale, img.shape[1]//scale),img.shape[2])
name = filename.split('.')
io.imsave(name[0] + '_' + str(scale) +'.png', img_res)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
